# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a figure and axes objects

# %%
fig, ax = plt.subplots(nrows =1, ncols = 1)
print(type(fig))
print(type(ax))
#Ex:2
fig1,ax1 = plt.subplots(nrows=2,ncols=2)
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig.get_size_inches()
# Out:
# array([6., 4.])

# %%
fig.set_size_inches(15,4)
fig.suptitle('Figure Title')
fig

# %%
print (fig.get_children())
fig.set_facecolor('C9')
ax.set_facecolor('.8')
fig
#c[0-9] is some color standard
# Out:
# [<matplotlib.patches.Rectangle object at 0x0000017FE58A2630>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000017FE6B17A58>, Text(0.5,0.98,'Figure Title')]

# %%
#Axes function

# %%
ax_children = ax.get_children()
ax_children
# Out:
# ...
#  Text(0.5,1,''),
#  Text(0,1,''),
#  Text(1,1,''),
# ...

# %%
#Spines can be accessed by
spines = ax.spines
spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x17fe6b17358>),
#              ('right', <matplotlib.spines.Spine at 0x17fe6b09e48>),
#              ('bottom', <matplotlib.spines.Spine at 0x17fe6b09ba8>),
#              ('top', <matplotlib.spines.Spine at 0x17fe6b09080>)])

# %%
spine_top = spines['top']
spine_top.set_visible(False)

spine_right = spines['right']
spine_right.set_visible(False)

spine_left = spines['left']
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_linewidth(5)
fig

# %%
#axies object can be accessed directly using xaxis or yaxis

# %%
ax.xaxis,ax.yaxis
# Out:
# (<matplotlib.axis.XAxis at 0x17fe6b09ac8>,
#  <matplotlib.axis.YAxis at 0x17fe6b21390>)

# %%
ax.xaxis.grid() is False,ax.yaxis.grid() is False
# Out:
# (False, False)

# %%
ax.xaxis.grid(True,which ='major',linewidth ='3')
ax.yaxis.grid(True)
fig

# %%
ax.xaxis.set_label_text('X-Axis')
ax.yaxis.set_label_text('Y-Axis')

print(ax.xaxis.get_units())
# Out:
# None
